# %%
#Criar variavel com a georeferência da area a ser estudada(instalar geopandas,)

#import dos dados
#transformar dados
#selecionar dados a serem estudados
# analise exploratória
#plotar dados
#salvar e disponibilizar dados

# %%
import geopandas as gpd
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# Locale: Utilizado para formatação de datas, valores, dias de acordo com a região que queremos.
import locale 
#Warnings: Possui detalhes sobre os avisos e alertas que aparecem, porém podemos utiliza-lo também para que os alertas de
#futuras atualizações e metodos depreciados não sejam exibidos
import warnings
warnings.filterwarnings("ignore")
#comando utilizado para exibir todas as colunas
pd.set_option('display.max_columns',None)
from shapely.geometry import point
from shapely.geometry import geometry
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_2380\2949445857.py in <module>
#      12 pd.set_option('display.max_columns',None)
#      13 from shapely.geometry import point
# ---> 14 from shapely.geometry import geometry
#
# ImportError: cannot import name 'geometry' from 'shapely.geometry' (C:\Users\User\anaconda3\lib\site-packages\shapely\geometry\__init__.py)

# %% [markdown]
# Gerando dados geoespaciais para criarmos o mapa:
# #dados importados do site do IBGE: https://www.ibge.gov.br/geocienciasorganizacao-do-territorio/malhas-territoriais/15774-malhas.html?=&t=acesso-ao-produto

# %%
#importando arquivo contendo georeferencia
dados_municipios=gpd.read_file("SP_Municipios_2021/")
dados_municipios.head()
# Out:
#     CD_MUN            NM_MUN SIGLA  AREA_KM2  \
# 0  3500105        Adamantina    SP   411.987
# 1  3500204            Adolfo    SP   211.055
# 2  3500303             Aguaí    SP   474.554
# 3  3500402    Águas da Prata    SP   142.673
# 4  3500501  Águas de Lindóia    SP    60.126
#
#                                             geometry
# 0  POLYGON ((-51.05425 -21.40465, -51.05300 -21.4...
# 1  POLYGON ((-49.65795 -21.20333, -49.65645 -21.2...
# 2  POLYGON ((-46.97640 -21.96818, -46.97599 -21.9...
# 3  POLYGON ((-46.73501 -21.81891, -46.73431 -21.8...
# 4  POLYGON ((-46.60614 -22.44173, -46.60347 -22.4...

# %%
#type(dados_municipios)

# %%
#aqui estamoos visualizando os dados contidos geografico do Estado de SP separado por municipio
dados_municipios.plot()
# Out:
# <AxesSubplot:>

# %%
# aqui temos uam melhor visualização dos dados
#gdf_municipios_sp=dados_municipios.plot(figsize=(10,5),facecolor='white',edgecolor='black')
#plt.show()

# %%
#Aqui vamos salvar o mapa que cria
dados_municipios.to_file('dadosmunicipios.json',driver='GeoJSON')

# %% [markdown]
# Agora vamos importar e analisar os dados

# %%
# Criando variavel principal
dados_rveiculos=pd.read_csv('DadosBO_2022_10_roubo_de_veiculos_sp.csv',encoding='ISO-8859-1', sep = ';')

# %%
dados_rveiculos.head()
# Out:
#    ANO_BO   NUM_BO NUMERO_BOLETIM       BO_INICIADO        BO_EMITIDO  \
# 0    2022  1710084   1710084/2022  01/10/2022 00:03  01/10/2022 00:03
# 1    2022  1710085   1710085/2022  01/10/2022 00:08  01/10/2022 00:08
# 2    2022     2381      2381/2022  01/10/2022 00:17  01/10/2022 00:17
# 3    2022     7423      7423/2022  01/10/2022 00:20  01/10/2022 00:20
# 4    2022  1710093   1710093/2022  01/10/2022 00:28  01/10/2022 00:28
#
#   DATAOCORRENCIA HORAOCORRENCIA PERIDOOCORRENCIA DATACOMUNICACAO  \
# 0     30/09/2022          20:30          A NOITE      30/09/2022
# 1     30/09/2022          18:00          A NOITE      30/09/2022
# 2     30/09/2022          23:30          A NOITE      30/09/2022
# 3     30/09/2022          20:00          A NOITE      30/09/2022
# 4     30/09/2022          20:00          A NOITE      30/09/2022
#
#      DATAELABORACAO    BO_AUTORIA FLAGRANTE NUMERO_BOLETIM_PRINCIPAL  \
# 0  01/10/2022 00:03  Desconhecida       Não                      NaN
# 1  01/10/2022 00:08  Desconhecida       Não                      NaN
# 2  01/10/2022 00:17  Desconhecida       Não                      NaN
# 3  01/10/2022 00:20     Conhecida       Sim                      NaN
# 4  01/10/2022 00:28  Desconhecida       Não                      NaN
#
#                        LOGRADOURO  NUMERO          BAIRRO    CIDADE  UF  \
# 0               RUA JORGE NEWBERY      92          JACANA   S.PAULO  SP
# 1                   RUA PARATINGA      81       CONCEICAO   DIADEMA  SP
# 2               RUA JOSE RAFAELLI     272         SOCORRO   S.PAULO  SP
# 3  Avenida Senador Lacerda Franco     970  Jardim do Lago  CAMPINAS  SP
# 4   Avenida Carlos Caldeira Filho      31       Vila Prel   S.PAULO  SP
#
#        LATITUDE    LONGITUDE                   DESCRICAOLOCAL  EXAME  \
# 0  -23,48104899  -46,5660764  Garagem ou abrigo de residência    NaN
# 1  -23,70204035  -46,6204273                      Via pública    NaN
# 2  -23,66683992  -46,7226596                      Via pública    NaN
# 3    -22,936142  -47,0888835                      Via pública    NaN
# 4   -23,6459599  -46,7537041                      Via pública    NaN
#
#                 SOLUCAO            DELEGACIA_NOME DELEGACIA_CIRCUNSCRICAO  \
# 0  BO PARA INVESTIGAÇÃO      DELEGACIA ELETRONICA         73º D.P. JACANA
# 1  BO PARA INVESTIGAÇÃO      DELEGACIA ELETRONICA        01º D.P. DIADEMA
# 2  BO PARA INVESTIGAÇÃO         102º D.P. SOCORRO       102º D.P. SOCORRO
# 3     BO PARA FLAGRANTE  PLANTÃO - 01 DP CAMPINAS       02º D.P. CAMPINAS
# 4  BO PARA INVESTIGAÇÃO      DELEGACIA ELETRONICA    37º D.P. CAMPO LIMPO
#
#                                     ESPECIE                     RUBRICA  \
# 0  Título II - Patrimônio (arts. 155 a 183)  Roubo (art. 157) - VEICULO
# 1  Título II - Patrimônio (arts. 155 a 183)  Roubo (art. 157) - VEICULO
# 2  Título II - Patrimônio (arts. 155 a 183)  Roubo (art. 157) - VEICULO
# 3  Título II - Patrimônio (arts. 155 a 183)  Roubo (art. 157) - VEICULO
# 4  Título II - Patrimônio (arts. 155 a 183)  Roubo (art. 157) - VEICULO
#
#   DESDOBRAMENTO     STATUS TIPOPESSOA VITIMAFATAL NATURALIDADE NACIONALIDADE  \
# 0           NaN  Consumado        NaN         NaN          NaN           NaN
# 1           NaN  Consumado        NaN         NaN          NaN           NaN
# 2           NaN  Consumado        NaN         NaN          NaN           NaN
# 3           NaN  Consumado        NaN         NaN          NaN           NaN
# 4           NaN  Consumado        NaN         NaN          NaN           NaN
#
#   SEXO DATANASCIMENTO  IDADE ESTADOCIVIL PROFISSAO GRAUINSTRUCAO  CORCUTIS  \
# 0  NaN            NaN    NaN         NaN       NaN           NaN       NaN
# 1  NaN            NaN    NaN         NaN       NaN           NaN       NaN
# 2  NaN            NaN    NaN         NaN       NaN           NaN       NaN
# 3  NaN            NaN    NaN         NaN       NaN           NaN       NaN
# 4  NaN            NaN    NaN         NaN       NaN           NaN       NaN
#
#   NATUREZAVINCULADA TIPOVINCULO  RELACIONAMENTO  PARENTESCO PLACA_VEICULO  \
# 0               NaN         NaN             NaN         NaN       EUX4246
# 1               NaN         NaN             NaN         NaN       DXF9J96
# 2               NaN         NaN             NaN         NaN       FNW7B16
# 3               NaN         NaN             NaN         NaN       GBT1A77
# 4               NaN         NaN             NaN         NaN       GEA7G37
#
#   UF_VEICULO CIDADE_VEICULO DESCR_COR_VEICULO       DESCR_MARCA_VEICULO  \
# 0         SP        S.PAULO             Prata        HONDA/CITY DX FLEX
# 1         SP        DIADEMA          Vermelho          I/TOYOTA COROLLA
# 2         SP        S.PAULO            Branco             HONDA/ADV 150
# 3         SP       CAMPINAS             Preta  I/TOYOTA HILUX CDSRXA4FD
# 4         SP        S.PAULO              Azul         YAMAHA/FZ25 FAZER
#
#    ANO_FABRICACAO  ANO_MODELO DESCR_TIPO_VEICULO  QUANT_CELULAR  MARCA_CELULAR
# 0          2011.0         NaN          AUTOMOVEL            NaN            NaN
# 1          2022.0         NaN          AUTOMOVEL            NaN            NaN
# 2          2021.0      2022.0           MOTONETA            NaN            NaN
# 3          2022.0      2022.0        CAMINHONETE            NaN            NaN
# 4          2022.0         NaN          MOTOCICLO            NaN            NaN

# %%
# verificar como estão organizados os dados de latidute e  longitude no nosso mapa
dados_rveiculos=dados_rveiculos[['LATITUDE','LONGITUDE']]

# %%
dados_rveiculos.info()
#Aqui estamos vendo que existem celulas onde temos ados núlos, sendo assim não podemos utilizar estas células
dados_rveiculos.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13839 entries, 0 to 13838
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   LATITUDE   12573 non-null  object
#  1   LONGITUDE  12573 non-null  object
# dtypes: object(2)
# memory usage: 216.4+ KB
# LATITUDE     1266
# LONGITUDE    1266
# dtype: int64

# %%
dados_rveiculos=dados_rveiculos.dropna(subset= ['LATITUDE','LONGITUDE'])
dados_rveiculos.info()
dados_rveiculos.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 12573 entries, 0 to 13838
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   LATITUDE   12573 non-null  object
#  1   LONGITUDE  12573 non-null  object
# dtypes: object(2)
# memory usage: 294.7+ KB
# LATITUDE     0
# LONGITUDE    0
# dtype: int64

# %% [markdown]
# Linhas com os valores núlos foram limpas, podemos ver que diminuimos a quantidade de linhas, porém não interfere no modelo

# %%
dados_rveiculos['geometry'] = None

# %%
for index, row in dados_rveiculos.iterrows():
    dados_rveiculos.loc[index,'geometry']= point(row.LATITUDE, row.LONGITUDE)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_2380\4007634837.py in <module>
#       1 for index, row in dados_rveiculos.iterrows():
# ----> 2     dados_rveiculos.loc[index,'geometry']= point(row.LATITUDE, row.LONGITUDE)
#
# TypeError: 'module' object is not callable
